# %% [markdown]
# <a href="https://colab.research.google.com/github/pbarizza/ML-course-2025/blob/main/lesson01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import numpy as np

# import pandas
import pandas as pd

# import graphical libraries
import seaborn as sns
import matplotlib.pyplot as plt

# import sklean modules
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# import the adverising dataset from Github
advertising_df = pd.read_csv('https://raw.githubusercontent.com/pbarizza/ML-course-2025/refs/heads/main/lesson-01/advertising.csv')
advertising_df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
X = advertising_df.drop('Sales',axis=1)
# alternatiely
X = advertising_df[['TV','Radio','Newspaper']]
X.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y=advertising_df['Sales']
y.head()
y.tail()
# Out:
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, dtype: float64

# %%
y.shape
X.shape
# Out:
# (200, 3)

# %%
# prompt: split the dataset in train test

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=42)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (40,)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
model.predict(X_test)
# Out:
# array([17.0347724 , 20.40974033, 23.72398873,  9.27278518, 21.68271879,
#        12.56940161, 21.08119452,  8.69035045, 17.23701254, 16.66657475,
#         8.92396497,  8.4817344 , 18.2075123 ,  8.06750728, 12.64550975,
#        14.93162809,  8.12814594, 17.89876565, 11.00880637, 20.47832788,
#        20.80631846, 12.59883297, 10.9051829 , 22.38854775,  9.41796094,
#         7.92506736, 20.83908497, 13.81520938, 10.77080925,  7.92682509,
#        15.95947357, 10.63490851, 20.80292008, 10.43434164, 21.5784752 ,
#        21.18364487, 12.12821771, 22.80953262, 12.60992766,  6.46441252])

# %%
predicted_df = pd.DataFrame({'Actual':y_test,'Predicted':model.predict(X_test), 'Difference':y_test-model.predict(X_test)})
predicted_df.head()
# Out:
#      Actual  Predicted  Difference
# 95     16.9  17.034772   -0.134772
# 15     22.4  20.409740    1.990260
# 30     21.4  23.723989   -2.323989
# 158     7.3   9.272785   -1.972785
# 128    24.7  21.682719    3.017281

# %%
mae = abs(predicted_df['Actual']-predicted_df['Predicted'])
mse = (predicted_df['Actual'])**2-(predicted_df['Predicted'])**2
predicted_df['MAE'] = mae
predicted_df['MSE'] = mse
predicted_df
# Out:
#      Actual  Predicted  Difference       MAE         MSE
# 95     16.9  17.034772   -0.134772  0.134772   -4.573471
# 15     22.4  20.409740    1.990260  1.990260   85.202500
# 30     21.4  23.723989   -2.323989  2.323989 -104.867641
# 158     7.3   9.272785   -1.972785  1.972785  -32.694545
# 128    24.7  21.682719    3.017281  3.017281  139.949706
# 115    12.6  12.569402    0.030598  0.030598    0.770143
# 69     22.3  21.081195    1.218805  1.218805   52.873238
# 170     8.4   8.690350   -0.290350  0.290350   -4.962191
# 174    16.5  17.237013   -0.737013  0.737013  -24.864601
# 45     16.1  16.666575   -0.566575  0.566575  -18.564714
# 66     11.0   8.923965    2.076035  2.076035   41.362849
# 182     8.7   8.481734    0.218266  0.218266    3.750182
# 165    16.9  18.207512   -1.307512  1.307512  -45.903504
# 78      5.3   8.067507   -2.767507  2.767507  -36.994674
# 186    10.3  12.645510   -2.345510  2.345510  -53.818917
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mean_squared_error(y_test,model.predict(X_test))
# Out:
# 2.9077569102710896

# %%
mean_absolute_error(y_test,model.predict(X_test))
# Out:
# 1.2748262109549338

# %%
predicted_df[]

# %%
model.score(X_test,y_test)
# Out:
# 0.9059011844150826

# %%
model.coef_
# Out:
# array([0.05450927, 0.10094536, 0.00433665])

# %%
model.intercept_
# Out:
# np.float64(4.714126402214127)

# %%
import joblib
joblib.dump(model, 'linear_regression_model.pkl')
# Out:
# ['linear_regression_model.pkl']
